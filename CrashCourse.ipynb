# %% [markdown]
# CrashCourse
# ===========
#
# Crash course for Olin College ReadML cocurricular. Do this at your own pace; we'll be around if you have any questions/tangential witty conversation starters. :D
#
#
# ####Notes to self (for Emily/Madison)
#
# - Planning logistics for classroom setup: Linux install/terminal practice stuff should be a pdf, and then now they have the ability to open the ipython notebook and start this section! :)
# - Should this be split into three "episodes"/seminars or done mostly in one day in a classroom?
#
#
# Linux and the Command Line
# ---------------------------
#
# ### Installing from USB
#
# When your computer begins to boot up, hold down the F12 key to bring up the One-Time Boot Menu.  From here, you can select your USB stick to boot from.  An Ubuntu install screen should appear. Ubuntu is a linux distribution (a.k.a flavor).
#
# For the most part, you can use the default settings when installing.  If you have more questions, feel free to ask us about details.
#
# Make sure to check the "Install updates" button to make sure your Ubuntu partition is ready to go after installing.
#
# This will set aside a portion of your hard drive (a partition) to be used for the Ubuntu operating system.  Your Windows operating system installed by default will no longer be able to access this space, so make sure to leave your windows drive some room to expand.  You can drag the sliders around to choose how much space to allocate for Ubuntu -- 50 GB is probably plenty for now.  You can extend the size of your Ubuntu drive later.
#
# The install process shouldn't take more than 30 minutes.
#
# When you reboot your computer, you'll be presented with a dialog to select which operating system you'd like to use.  If you don't watch as your computer boots up, it will likely choose an operating system for you.  After this installation, Ubuntu will be your default operating system.
#
#
# ### Getting around Linux
#
# #### Opening up a terminal
# The keyboard shortcut ctrl-alt-t should get you to a terminal.
#
# #### Where am I?
# ```bash
# $ ls
# ```
#
# #### Getting places
# Linux is case sensitive, so make sure to catch your typos.
# P.S.: if you start typing a word, and then hit tab, the terminal will help you out with autocomplete.
# ```bash
# $ cd Documents
# ```
#
# #### Install all the things!
# ```bash
# $ apt-get install git
# E: Could not open lock file /var/lib/dpkg/lock - open (13: Permission denied)
# E: Unable to lock the administration directory (/var/lib/dpkg/), are you root?
# ```
#
# In fact, you are not root.  For some operations in linux you need to provide your password in order to make sure you want to complete an action.  Let's try this again!
#
# ```bash
# $ sudo apt-get install git
# ```
#
# After you enter in your password, the `git` software package should be installed on your computer.  Think of apt-get like your phone's app store.  Its technically a software repository: a remote location where software installation files are stored.
#
# Let's install a few more things that you'll want to have on your Ubuntu partition:
#
# ```bash
# $ sudo apt-get python-pip python-numpy python-scipy python-matplotlib ipython ipython-notebook python-pandas python-sympy python-nose
# ```
#
# Pip is python package manager, much like apt-get is Ubuntu package manager.  Let's install something with pip.  Scikit-learn is a python library (packaged, third party code) for machine learning -- you'll want it for later.
#
# ```bash
# $ sudo pip install scikit-learn
# ```
# #### Installing a text editor (your best friend)
#
# To install Sublime, the text editor of choice at Olin, you'll need to add a new repository (source for software) to apt-get.  Then you'll need to run `sudo apt-get update`, which refreshes the list of repositories used by apt-get.  Finally, you can install Sublime with apt-get like you're used to.
#
# ```bash
# $ sudo add-apt-repository ppa:webupd8team/sublime-text-3
# $ sudo apt-get update
# $ sudo apt-get install sublime-text-installer
# ```
#
# #### Making directories
# You can make a new directory (folder) using `mkdir`.
# ```bash
# $ mkdir SHUML # you'll learn the acronym later
# ```
#
# #### Make a blank file
# And check out Sublime Text!
# ```bash
# $ subl paul
# ```
#
# #### Removing files
# You probably don't actually want to keep that. By the way, the removal is permanent. (not your typical recycling bin)
# ```bash
# $ rm paul
# ```
#
# #### Removing directories
# Let's clean up after ourselves.
# ```bash
# $ cd .. # go back a directory
# $ rmdir SHUML # remove a file
# ```
# #### Make a github account
# Github is an awesome website for people to save and share their project code. Make an account if you don't have one already and we'll have a more in-depth tutorial for it in a week or two.
#
# #### Onwards!
# Now that you have a shiny new operating system and all of these fun programs, let's get started and write some code.

# %% [markdown]
# Programming in Python!
# ---------------------------
#
# Now that you know how to navigate through Ubuntu, let's start writing some programs!
#
# #### Hello world! Learn the art of printing
# #### Variables!
# #### Control flow - if/else, for, while!
# #### Lists, tuples, and dictionaries - containers for things!
# #### Mutability...
# #### Functions! wow, such abstraction
# #### Commenting your code - notes to a future self (and the universe)
# #### Real code, real talk - applications of programming in the real world
# #### Code practices - developing good habits now instead of fixing bad ones later
# #### Debugging - don't give up! also, the internet is your friend (external resources)
# #### Sentimental value
# #### Onwards! - OOP, recursion, other languages...

# %%
print 'Hello world!'
# Out:
# Hello world!

# %% [markdown]
# Version Control: Github mastery
# -------------------------------
#
# (this will eventually be in a README/markdown file instead)
# (work in progress)
#
# #### Why? Motivations to use github!
# - Don't use dropbox or google drive for code.
# - Everyone has a local copy of the code! :) You don't want one person's bugs to affect the rest of the team.
# - Make sure you can trace a bug back to a particular point in time (find out exactly what happened when).
# - Pull requests - giving people an opportunity to approve a modification to the code.
# - Ability to revert back to previous versions of the code - so it's safe to experiment and code new things without fear. (No control-Z sprees of panic!)
#
# #### What's git? How does it work?
# - git refers to the version control system.
# - Github is the collaborative code website for users to share their code with others and keep track of their projects over time.
# - An overview of how to use git: Read the "basic usage" section of this webpage. Feel free to read more if you're interested though!:
# http://marklodato.github.io/visual-git-guide/index-en.html
#
# #### Setting things up on your computer
# - You should already have git installed on your system. If not, then simply
#
# ```
#    $ sudo apt-get install git
# ```
#
# #### #### Your first github repository :D and getting familiar with commands
#
# Clone this repository!
# ```
#    $ clone ...
# ```
#
# Open the text file called "Minions.txt"
# Add your github username to the list.
# When you're done, save the text file and get ready to push your updates.
#
# ```
#    $ git status ... # it's a good habit to check what updates are going to be pushed
#    $ git add Minions.txt # stage the file
#    $ git commit -m "Updated Minions.txt with github username"
#    $ git push #pushes your updates to the github website
#
# ```
#
# Oh noes! it turns out that you have a *dundundun* MERGE CONFLICT!
# But fear not, young code warrior! You can handle this...
#
# - to be continued
# - The hyphenated options/shortcuts
# - maybe mention colors/ssh?
# - git config name and email things
#
# #### Social github: fork, branch, or just a collaborator setup?
# pcottle.github.io
#
# merging!
# origin/upstream/remote/etc terminology
#
# #### Dundundun - Conflicts
#
# #### HTTPs vs SSH
